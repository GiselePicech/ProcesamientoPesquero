# %% [markdown]
# ##Librerías

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn
from sklearn.utils.fixes import sklearn
from sklearn.preprocessing import OrdinalEncoder
from pandas.plotting import autocorrelation_plot
import datetime as dt
from datetime import datetime
import statsmodels as sm 
import statsmodels.api as sm_api
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ## Base de Datos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Ingesta de datos
pesca2 = pd.read_excel('/content/drive/MyDrive/SMyS/maestro_produccion_total.xlsx')

# %%
#Muestra de datos
pesca2.head()
# Out:
#        Fecha    RInt  Dueño2 Especie2         Materia Prima  Cajones  \
# 0 2022-07-22  5504.0    17.0   Almeja  Almeja entera fresca     41.0
# 1 2022-08-12  5549.0    10.0   Almeja  Almeja entera fresca     53.0
# 2 2022-05-01  5331.0     6.0   Almeja  Almeja entera fresca     10.0
# 3 2022-03-28  5240.0    14.0   Almeja  Almeja entera fresca      4.0
# 4 2022-04-07  5262.0    11.0   Almeja  Almeja entera fresca      7.0
#
#    PesoXcajon    KgBr  Desp     KgN     ProductoTerminado     IAC    KGT  \
# 0        46.8  1918.8   0.0  1918.8  Almeja 1/2 valva IQF  1432.0  842.0
# 1        48.8  2586.4   0.0  2586.4  Almeja 1/2 valva IQF  1438.0  216.0
# 2        45.0   450.0   0.0   450.0  Almeja entera fresca     1.0  450.0
# 3        40.0   160.0   0.0   160.0  Almeja entera fresca     1.0  160.0
# 4        40.0   280.0   0.0   280.0  Almeja entera fresca     1.0  280.0
#
#     Rinde
# 0  0.4388
# 1  0.0835
# 2  1.0000
# 3  1.0000
# 4  1.0000

# %%
#Tipos de datos
pesca2.dtypes
# Out:
# Fecha                datetime64[ns]
# RInt                        float64
# Dueño2                      float64
# Especie2                     object
# Materia Prima                object
# Cajones                     float64
# PesoXcajon                  float64
# KgBr                        float64
# Desp                        float64
# KgN                         float64
# ProductoTerminado            object
# IAC                         float64
# KGT                         float64
# Rinde                       float64
# dtype: object

# %%
#Cantidad de registros y columnas
pesca2.shape
# Out:
# (4118, 14)

# %%
pesca1 = pesca2.drop("RInt", axis=1)

# %%
pesca = pesca1.drop("IAC", axis=1)

# %%
#Cantidad de registros y columnas
pesca.shape
# Out:
# (4118, 12)

# %%
#Medidas generales
pesca.describe(include='all')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#                       Fecha       Dueño2    Especie2  \
# count                  4118  4118.000000        4118
# unique                  920          NaN          33
# top     2021-08-01 00:00:00          NaN  Langostino
# freq                     23          NaN        1883
# first   2018-01-02 00:00:00          NaN         NaN
# last    2022-09-07 00:00:00          NaN         NaN
# mean                    NaN    22.594949         NaN
# std                     NaN    14.509755         NaN
# min                     NaN     1.000000         NaN
# 25%                     NaN    10.000000         NaN
# 50%                     NaN    16.000000         NaN
# 75%                     NaN    34.000000         NaN
# max                     NaN    55.000000         NaN
#
#                    Materia Prima      Cajones   PesoXcajon          KgBr  \
# count                       4118  4118.000000  4118.000000   4118.000000
# unique                       102          NaN          NaN           NaN
# top     Langostino entero fresco          NaN          NaN           NaN
# freq                        1766          NaN          NaN           NaN
# first                        NaN          NaN          NaN           NaN
# last                         NaN          NaN          NaN           NaN
# mean                         NaN   201.985673    22.862285   3961.977734
# std                          NaN   233.504160     7.959118   4330.330733
# min                          NaN     1.000000     4.000000      4.000000
# 25%                          NaN    31.000000    17.402500    800.200000
# 50%                          NaN    83.000000    21.000000   2128.000000
# 75%                          NaN   312.000000    27.000000   5816.250000
# max                          NaN  1200.000000   193.000000  22701.000000
#
#                Desp           KgN ProductoTerminado           KGT        Rinde
# count   4118.000000   4118.000000              4118   4118.000000  4118.000000
# unique          NaN           NaN               228           NaN          NaN
# top             NaN           NaN  Vieira callo IQF           NaN          NaN
# freq            NaN           NaN               470           NaN          NaN
# first           NaN           NaN               NaN           NaN          NaN
# last            NaN           NaN               NaN           NaN          NaN
# mean       0.044529   3888.203497               NaN    914.492865     0.376811
# std        0.085727   4349.494952               NaN   1258.111659     0.339411
# min        0.000000      4.000000               NaN      3.200000     0.000800
# 25%        0.000000    722.400000               NaN    180.000000     0.146300
# 50%        0.000000   1944.350000               NaN    431.000000     0.246050
# 75%        0.070000   5761.500000               NaN   1069.500000     0.494825
# max        0.680000  22701.000000               NaN  14030.000000     4.137900

# %%
#Control de valores nulos
pesca.isna().sum()
# Out:
# Fecha                0
# Dueño2               0
# Especie2             0
# Materia Prima        0
# Cajones              0
# PesoXcajon           0
# KgBr                 0
# Desp                 0
# KgN                  0
# ProductoTerminado    0
# KGT                  0
# Rinde                0
# dtype: int64

# %%
#Cantidad de valores unicos por rango
pesca.nunique()
# Out:
# Fecha                 920
# Dueño2                 54
# Especie2               33
# Materia Prima         102
# Cajones               474
# PesoXcajon            659
# KgBr                 2057
# Desp                   50
# KgN                  2299
# ProductoTerminado     228
# KGT                  1184
# Rinde                2657
# dtype: int64

# %%
#Matriz de correlacion - Metodo Pearson
pescaD = pesca.drop("Dueño2", axis=1)
pesca_df2=pd.DataFrame(pescaD)
pesca_df2.corr(method = 'pearson')
# Out:
#              Cajones  PesoXcajon      KgBr      Desp       KgN       KGT  \
# Cajones     1.000000   -0.352995  0.970215 -0.325306  0.972422  0.583397
# PesoXcajon -0.352995    1.000000 -0.227727  0.529348 -0.245478 -0.160218
# KgBr        0.970215   -0.227727  1.000000 -0.276000  0.999087  0.608381
# Desp       -0.325306    0.529348 -0.276000  1.000000 -0.308554 -0.231481
# KgN         0.972422   -0.245478  0.999087 -0.308554  1.000000  0.609900
# KGT         0.583397   -0.160218  0.608381 -0.231481  0.609900  1.000000
# Rinde      -0.364579   -0.055068 -0.379767 -0.146714 -0.373076  0.116096
#
#                Rinde
# Cajones    -0.364579
# PesoXcajon -0.055068
# KgBr       -0.379767
# Desp       -0.146714
# KgN        -0.373076
# KGT         0.116096
# Rinde       1.000000

# %% [markdown]
# ## Gráficos

# %%
#Matriz de correlacion - Metodo Pearson VISUALIZACION
plt.style.use('dark_background')
sns.heatmap(pescaD.corr(), annot=True, cmap="crest")
plt.show()

# %%
#Grafico de puntos - Cantidad de cajones vs. Kg Netos
plt.style.use('dark_background')
plt.scatter(pesca.Cajones , pesca.KgN, marker=".",facecolor='w')
plt.grid(False)
plt.show()

# %%
#Grafico de puntos - KG Brutos vs. Cantidad de Cajones
plt.style.use('dark_background')
plt.scatter(pesca.KgBr ,pesca.Cajones, marker=".",facecolor='w')
plt.grid(False)
plt.show()

# %%
#Grafico de puntos - KG Terminados vs. Kg Netos
plt.style.use('dark_background')
plt.scatter(pesca.KGT,pesca.KgN, marker=".",facecolor='w')
plt.grid(False)
plt.show()

# %%
#Suma de Rinde por Dueno
pesca[['Dueño2','Rinde']].groupby('Dueño2').sum().sort_values('Rinde', ascending=False)
# Out:
#            Rinde
# Dueño2
# 10.0    482.4379
# 43.0    148.0787
# 18.0    123.9163
# 16.0    103.3410
# 6.0      99.0986
# 34.0     75.7509
# 19.0     45.4919
# 30.0     41.3943
# 5.0      38.8312
# 28.0     36.3088
# 15.0     28.9405
# 14.0     25.2778
# 9.0      24.7127
# 4.0      22.5303
# 1.0      19.1507
# 26.0     18.3230
# 17.0     17.0231
# 50.0     15.9647
# 13.0     15.7561
# 48.0     13.1956
# 24.0     13.1651
# 20.0     13.1399
# 8.0      11.7429
# 42.0     11.4776
# 29.0     11.2554
# 35.0      8.3872
# 31.0      7.6865
# 41.0      6.7978
# 21.0      6.5531
# 27.0      5.4607
# 51.0      5.2220
# 23.0      5.0640
# 37.0      5.0232
# 54.0      4.5405
# 38.0      4.4519
# 53.0      4.0790
# 39.0      3.6637
# 25.0      3.5819
# 11.0      2.9926
# 52.0      2.9478
# 47.0      2.8328
# 12.0      2.0000
# 3.0       1.9992
# 36.0      1.7263
# 2.0       1.7196
# 45.0      1.6383
# 33.0      1.6004
# 46.0      1.3791
# 40.0      1.0719
# 22.0      0.9996
# 7.0       0.9341
# 44.0      0.5161
# 55.0      0.2834
# 49.0      0.2514

# %%
#Grafico de hexagonos - KG Brutos vs. Kg Netos
plt.style.use('dark_background')
pesca.plot.hexbin(x='KgBr', y='KgN', gridsize=12,cmap="gist_yarg")
plt.grid(False)
plt.show()

# %%
#Grafico de Autocorrelacion - Desperdicio
plt.style.use('dark_background')
autocorrelation_plot(pesca.Desp)
plt.grid(False)
plt.show()

# %%
#Grafico de puntos - Duenos vs. Rinde
df = pd.DataFrame(pesca,columns=['Dueño2','Rinde'])
plt.style.use('dark_background')
plt.scatter(df['Dueño2'], df['Rinde'], color='w', marker='o')
plt.title('Rinde por Dueño', fontsize=14)
plt.xlabel('Dueño', fontsize=14)
plt.ylabel('Rinde', fontsize=14)
plt.grid(False)
plt.show()

# %%
sns.set()

# %%
plt.style.use('dark_background')
sns.pairplot(pescaD, hue="Especie2", size=2)
#plt.grid(False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Selección de datos

# %%
especies = pesca[['Especie2','KGT']].groupby('Especie2').sum().sort_values('KGT',ascending=False)

# %%
#Filtro las especies por ranking de SumKGT > 15.000
dfEspecies = pd.DataFrame(especies)
especies_maxpesos = dfEspecies['KGT']>=15000
filtro_dfEspecies = dfEspecies[especies_maxpesos]
print(filtro_dfEspecies)
# Out:
#                    KGT
# Especie2
# Langostino  2709476.18
# Vieira       313694.20
# Mejillon     157711.98
# Merluza      157613.20
# Cornalito    142021.00
# Cholga       112852.45
# Cangrejo      63803.91
# Almeja        48419.70
# Pejerrey      15325.00

# %%
plt.style.use('dark_background')
filtro_dfEspecies.plot(kind='bar',facecolor='w',grid=False)

# %%
especiesKgN = pesca[['Especie2','KgN']].groupby('Especie2').sum().sort_values('KgN',ascending=False)
#Filtro las especies por ranking de SumKgN > 50.000
dfEspeciesKgN = pd.DataFrame(especiesKgN)
especies_maxpesosKgN = dfEspeciesKgN['KgN']>=50000
filtro_dfEspeciesKgN = dfEspeciesKgN[especies_maxpesosKgN]
print(filtro_dfEspeciesKgN)
# Out:
#                    KgN
# Especie2
# Langostino  12898832.6
# Vieira       1434869.3
# Merluza       469856.4
# Mejillon      352755.2
# Cholga        300321.6
# Cornalito     153069.8
# Almeja        150586.7
# Cangrejo       74390.6
# Abadejo        61884.7

# %%
plt.style.use('dark_background')
filtro_dfEspeciesKgN.plot(kind='bar',facecolor='w',grid=False)

# %%
especiesB = pesca[['Especie2','Rinde']].groupby('Especie2').sum().sort_values('Rinde',ascending=False)

# %%
#Filtro las especies por ranking de SumRinde > 20
dfEspeciesB = pd.DataFrame(especiesB)
especiesB_maxrinde = dfEspeciesB['Rinde']>=20
filtro_dfEspeciesB = dfEspeciesB[especiesB_maxrinde]
print(filtro_dfEspeciesB)
# Out:
#                Rinde
# Especie2
# Langostino  456.6039
# Vieira      219.6476
# Cornalito   206.6070
# Cangrejo    193.6871
# Mejillon    121.9721
# Cholga      116.8206
# Almeja       49.1189
# Merluza      43.0657
# Pejerrey     42.3364

# %%
plt.style.use('dark_background')
filtro_dfEspeciesB.plot(kind='bar',facecolor='w',grid=False)

# %%
#Creo tabla con especies Top 9 que SumRinde > 20 y SumKGT > 15.000
filtro_dfEspecies = pd.DataFrame(filtro_dfEspecies)
filtro_dfEspeciesB = pd.DataFrame(filtro_dfEspeciesB)
especiesAB = pd.merge(left = filtro_dfEspecies, right = filtro_dfEspeciesB, how = 'inner', left_on = 'Especie2', right_on = 'Especie2')
DFespeciesAB = pd.DataFrame(especiesAB)
especiesAB
# Out:
#                    KGT     Rinde
# Especie2
# Langostino  2709476.18  456.6039
# Vieira       313694.20  219.6476
# Mejillon     157711.98  121.9721
# Merluza      157613.20   43.0657
# Cornalito    142021.00  206.6070
# Cholga       112852.45  116.8206
# Cangrejo      63803.91  193.6871
# Almeja        48419.70   49.1189
# Pejerrey      15325.00   42.3364

# %%
especiesKN = pesca[['Especie2','KgN']].groupby('Especie2').sum().sort_values('KgN',ascending=False)

# %%
#Filtro las especies por ranking de SumKgN > 50.000
dfEspeciesKN = pd.DataFrame(especiesKN)
especies_maxpesosKN = dfEspeciesKN['KgN']>=50000
filtro_dfEspeciesKN = dfEspeciesKN[especies_maxpesosKN]
print(filtro_dfEspeciesKN)
# Out:
#                    KgN
# Especie2
# Langostino  12898832.6
# Vieira       1434869.3
# Merluza       469856.4
# Mejillon      352755.2
# Cholga        300321.6
# Cornalito     153069.8
# Almeja        150586.7
# Cangrejo       74390.6
# Abadejo        61884.7

# %%
#Creo tabla con especies Top 9 que SumRinde > 20, SumKGT > 15.000 y SumKgN > 50.000
filtro_dfEspeciesKN = pd.DataFrame(filtro_dfEspeciesKN)
especiesABKN = pd.merge(left = DFespeciesAB, right = filtro_dfEspeciesKN, how = 'inner', left_on = 'Especie2', right_on = 'Especie2')
DFespeciesABKN = pd.DataFrame(especiesABKN)
especiesABKN
# Out:
#                    KGT     Rinde         KgN
# Especie2
# Langostino  2709476.18  456.6039  12898832.6
# Vieira       313694.20  219.6476   1434869.3
# Mejillon     157711.98  121.9721    352755.2
# Merluza      157613.20   43.0657    469856.4
# Cornalito    142021.00  206.6070    153069.8
# Cholga       112852.45  116.8206    300321.6
# Cangrejo      63803.91  193.6871     74390.6
# Almeja        48419.70   49.1189    150586.7

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots()
yKGT = especiesABKN['KGT']
zRinde = especiesABKN['Rinde']
wKgN = especiesABKN['KgN']
ax.plot(wKgN, color = 'c',label ="KgN")
ax.plot(yKGT, color = 'tab:grey',label ='KGT')
ax.plot(zRinde, color = 'w',label ='Rinde')
ax.grid(False)
plt.legend()
plt.gcf().set_size_inches(9, 4)
plt.tight_layout()
plt.show()

# %%
#Filtro las base por especies (9) que SumKGT > 15.000 y SumRinde > 20
especies_top = especiesAB.index
filtro_TopEsp = pesca_df2[pesca_df2['Especie2'].isin(especies_top)]
filtro_TopEsp.head()
# Out:
#        Fecha Especie2         Materia Prima  Cajones  PesoXcajon    KgBr  \
# 0 2022-07-22   Almeja  Almeja entera fresca     41.0        46.8  1918.8
# 1 2022-08-12   Almeja  Almeja entera fresca     53.0        48.8  2586.4
# 2 2022-05-01   Almeja  Almeja entera fresca     10.0        45.0   450.0
# 3 2022-03-28   Almeja  Almeja entera fresca      4.0        40.0   160.0
# 4 2022-04-07   Almeja  Almeja entera fresca      7.0        40.0   280.0
#
#    Desp     KgN     ProductoTerminado    KGT   Rinde
# 0   0.0  1918.8  Almeja 1/2 valva IQF  842.0  0.4388
# 1   0.0  2586.4  Almeja 1/2 valva IQF  216.0  0.0835
# 2   0.0   450.0  Almeja entera fresca  450.0  1.0000
# 3   0.0   160.0  Almeja entera fresca  160.0  1.0000
# 4   0.0   280.0  Almeja entera fresca  280.0  1.0000

# %%
filtro_TopEsp.shape
# Out:
# (3971, 11)

# %%
#Fitro de Especie "LANGOSTINO"
filtro_Lang = pesca_df2[pesca_df2['Especie2']=='Langostino']
filtro_Lang.head()
# Out:
#          Fecha    Especie2             Materia Prima  Cajones  PesoXcajon  \
# 276 2021-06-17  Langostino  Langostino entero fresco    229.0       18.00
# 277 2022-01-13  Langostino  Langostino entero fresco    381.0       16.40
# 278 2022-01-13  Langostino  Langostino entero fresco    300.0       18.25
# 279 2022-01-13  Langostino  Langostino entero fresco    249.0       18.25
# 280 2022-01-13  Langostino  Langostino entero fresco    421.0       16.88
#
#         KgBr  Desp     KgN ProductoTerminado     KGT   Rinde
# 276  4122.00   0.0  4122.0      Lg. C1 block   516.0  0.1252
# 277  6248.40   0.0  6248.4      Lg. C1 block  3366.0  0.5387
# 278  5475.00   0.0  5475.0      Lg. C1 block  2106.0  0.3847
# 279  4544.25   0.0  4544.3      Lg. C1 block  1854.0  0.4080
# 280  7106.48   0.0  7106.5      Lg. C1 block  4230.0  0.5952

# %%
filtro_Lang.shape
# Out:
# (1883, 11)

# %%
langostino9 = filtro_Lang
langostino8 = langostino9.drop("Especie2", axis=1)
langostino7 = langostino8.drop("Materia Prima", axis=1)
langostino6 = langostino7.drop("Cajones", axis=1)
langostino5 = langostino6.drop("PesoXcajon", axis=1)
langostino4 = langostino5.drop("KgBr", axis=1)
langostino3 = langostino4.drop("Desp", axis=1)
langostino2 = langostino3.drop("ProductoTerminado", axis=1)
langostino1 = langostino2.drop("KGT", axis=1)
langostino = langostino1.drop("Rinde", axis=1)
langostino.head()
# Out:
#          Fecha     KgN
# 276 2021-06-17  4122.0
# 277 2022-01-13  6248.4
# 278 2022-01-13  5475.0
# 279 2022-01-13  4544.3
# 280 2022-01-13  7106.5

# %%
dfLangostino = pd.DataFrame(langostino)
dfLangostino = dfLangostino.sort_values(by='Fecha', ascending=True)
dfLangostino.dtypes
dfLangostino.head(10)
# Out:
#           Fecha     KgN
# 623  2018-01-02  6983.4
# 553  2018-01-02  6983.4
# 610  2018-01-02  6983.4
# 453  2018-01-02  6983.4
# 494  2018-01-03  7760.4
# 1233 2018-01-03  7760.4
# 491  2018-01-04  8762.2
# 627  2018-01-05  7938.0
# 541  2018-01-05  7938.0
# 495  2018-01-06  7051.8

# %%
x1 = dfLangostino['Fecha']
y1 = dfLangostino['KgN']
plt.style.use('dark_background')
plt.plot(x1, y1,color = 'w')
plt.gcf().set_size_inches(10, 5)
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# # **SERIE** **TEMPORAL**

# %%
#Prueba de Estacionalidad - Dickey-Fuller
resultadoEsta = adfuller(dfLangostino['KgN'])
print('ADF Statistic: %f' % resultadoEsta[0])
print('p-value: %f' % resultadoEsta[1])
# Out:
# ADF Statistic: -6.458759
# p-value: 0.000000

# %% [markdown]
# ## Es Estacionaria, proque p-value es < 0.05.

# %%
serieK = dfLangostino['KgN'].squeeze()
print(serieK)
# Out:
# 623     6983.4
# 553     6983.4
# 610     6983.4
# 453     6983.4
# 494     7760.4
#          ...
# 3333    2440.0
# 3357    2440.0
# 3346    3160.0
# 3358    3160.0
# 3171    3646.5
# Name: KgN, Length: 1883, dtype: float64

# %%
serieF = dfLangostino['Fecha'].squeeze()
print(serieF)
# Out:
# 623    2018-01-02
# 553    2018-01-02
# 610    2018-01-02
# 453    2018-01-02
# 494    2018-01-03
#           ...
# 3333   2022-08-05
# 3357   2022-08-05
# 3346   2022-08-25
# 3358   2022-08-25
# 3171   2022-09-05
# Name: Fecha, Length: 1883, dtype: datetime64[ns]

# %%
#Visualización de la serie temporal
serieK = dfLangostino['KgN'].squeeze()
xS = dfLangostino['Fecha']
yS = serieK
plt.style.use('dark_background')
plt.plot_date(xS, yS, linestyle='solid',marker='.',color='w')
plt.gcf().set_size_inches(12, 5)
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
#Filtro de Hodrick-Prescott para la separación de variables
serieK = dfLangostino['KgN'].squeeze()
ciclo, tendencia = sm_api.tsa.filters.hpfilter(serieK)
dfLangostino['ciclo'] = ciclo
dfLangostino['tendencia'] = tendencia
yV = dfLangostino[['KgN','ciclo','tendencia']]

# %%
plt.style.use('dark_background')
plt.plot_date(xS, yV)
plt.gcf().set_size_inches(8, 6)
plt.tight_layout()
plt.legend(yV)
plt.grid(False)
plt.show()

# %%
#Calculo de la media móvil
serieK = dfLangostino['KgN'].squeeze()
MedMov_KgN = serieK.rolling(window=5).mean()
dfLangostino['MedMov_KgN'] = MedMov_KgN
yMV = dfLangostino[['KgN','MedMov_KgN']]

# %%
plt.style.use('dark_background')
plt.plot_date(xS, yMV,linestyle='solid')
plt.gcf().set_size_inches(8, 6)
plt.tight_layout()
plt.legend(yMV)
plt.grid(False)
plt.show()

# %%
# ARIMA - Modelo
modeloK = sm.tsa.arima_model.ARIMA(serieK, order=(1, 0, 0))  #.iloc[1:]
resultadosK = modeloK.fit(disp=-1)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
pronosticoK = resultadosK.fittedvalues 
print(pronosticoK)
# Out:
# 623     6850.150080
# 553     6937.805807
# 610     6937.805807
# 453     6937.805807
# 494     6937.805807
#            ...
# 3333    2930.045407
# 3357    3949.023291
# 3346    3949.023291
# 3358    4422.660526
# 3171    4422.660526
# Length: 1883, dtype: float64

# %%
xF = dfLangostino['Fecha']
plt.style.use('dark_background')
plt.figure(figsize=(14,8))
plt.plot(xF,dfLangostino['KgN'],c='w',label='Real')
plt.plot(xF,pronosticoK, c='c', label='Predicción')
plt.ylabel("Kg. Netos")
plt.legend()
plt.title("Predicción Serie Temporal - ARIMA")
plt.grid(False)
plt.show()
